# %%
#spare: exec(compile(open("/var/lib/jupyter/notebooks/MainExec.py", "rb").read(), "SeparatedCommaned.py", 'exec'))
###### HOW TO USE #####
# 1. Click the "refresh kernel" button (it's beside the stop button)
# 2. Click ">| Run" button

# 3. Put in your file name (include the csv); then press enter. quotation marks are not needed

# 4. Wait for the simulation to complete. This step will check if an error is going to occur.
#    > This will take ~3 minutes

# 5. If everything went well, you will see: "SIMULATION COMPLETE", and will ask your permission to continue the run
#    > To continue run, fill "Y", then press ENTER
#    > as final confirmation, press ENTER again
#    > If otherwise an error was found, you can choose to continue the run anyway, or cancel it (fill "N", then press ENTER)


exec(compile(open("/var/lib/jupyter/notebooks/MainExec.py", "rb").read(), "SeparatedCommaned.py", 'exec'))

# exec(compile(open("/var/lib/jupyter/notebooks/MainExec.py", "rb").read(), "SeparatedCommaned.py", 'exec'))
# Out:
# File Name : CommandList_PMID-002_EXPID-STK-E007_Lieshout.B.csv
# Perform simulation? (Y/N)y
# /data/deck_calibration.json not found. Loading defaults
# Progress	: 0%
# ['labware_11' 'A1' 'labware_10' 'A3' '1050' '0' '1'
#  'Initial solvent distribution']
# Progress	: 1%
# ['labware_11' 'A1' 'labware_10' 'A4' '525' '0' '1'
#  'Initial solvent distribution']
# Progress	: 2%
# ['labware_11' 'A1' 'labware_9' 'A1' '787.5' '0' '1'
#  'Initial solvent distribution']
# Progress	: 3%
# ['labware_11' 'A1' 'labware_9' 'A2' '918.75' '0' '1'
#  'Initial solvent distribution']
# Progress	: 4%
# ['labware_11' 'A1' 'labware_9' 'A3' '984.375' '0' '1'
#  'Initial solvent distribution']
# Progress	: 5%
# ['labware_11' 'A1' 'labware_9' 'A4' '1017.1875' '0' '1'
#  'Initial solvent distribution']
# Progress	: 6%
# ['labware_11' 'A1' 'labware_9' 'A5' '1033.59375' '0' '1'
#  'Initial solvent distribution']
# Progress	: 7%
# ['labware_11' 'A1' 'labware_9' 'B1' '1041.796875' '0' '1'
#  'Initial solvent distribution']
# Progress	: 8%
# ['labware_11' 'A1' 'labware_9' 'B2' '1438.1103515625' '0' '1'
#  'Initial solvent distribution']
# Progress	: 8%
# ['labware_11' 'A1' 'labware_10' 'A5' '1050' '0' '1'
#  'Initial solvent distribution']
# Progress	: 9%
# ['labware_11' 'A1' 'labware_10' 'B1' '525' '0' '1'
#  'Initial solvent distribution']
# Progress	: 10%
# ['labware_11' 'A1' 'labware_9' 'B3' '787.5' '0' '1'
#  'Initial solvent distribution']
# Progress	: 11%
# ['labware_11' 'A1' 'labware_9' 'B4' '918.75' '0' '1'
#  'Initial solvent distribution']
# Progress	: 12%
# ['labware_11' 'A1' 'labware_9' 'B5' '984.375' '0' '1'
#  'Initial solvent distribution']
# Progress	: 13%
# ['labware_11' 'A1' 'labware_9' 'C1' '1017.1875' '0' '1'
#  'Initial solvent distribution']
# Progress	: 14%
# ['labware_11' 'A1' 'labware_9' 'C2' '1033.59375' '0' '1'
#  'Initial solvent distribution']
# Progress	: 15%
# ['labware_11' 'A1' 'labware_9' 'C3' '1041.796875' '0' '1'
#  'Initial solvent distribution']
# Progress	: 16%
# ['labware_11' 'A1' 'labware_9' 'C4' '1255.078125' '0' '1'
#  'Initial solvent distribution']
# Progress	: 17%
# ['labware_10' 'A1' 'labware_9' 'B2' '653.6865234375' '653.6865234375' '2'
#  'Initial stock dilution']
# Progress	: 18%
# ['labware_10' 'A2' 'labware_9' 'C4' '836.71875' '836.71875' '3'
#  'Initial stock dilution']
# Progress	: 19%
# ['labware_9' 'B2' 'labware_9' 'B1' '1041.796875' '1041.796875' '4'
#  'Serially diluting to  GEN 8 MED_A']
# Progress	: 20%
# ['labware_9' 'B1' 'labware_9' 'A5' '1033.59375' '1033.59375' '5'
#  'Serially diluting to  GEN 4 MED_A']
# Progress	: 21%
# ['labware_9' 'A5' 'labware_9' 'A4' '1017.1875' '1017.1875' '6'
#  'Serially diluting to  GEN 2 MED_A']
# Progress	: 22%
# ['labware_9' 'A4' 'labware_9' 'A3' '984.375' '984.375' '7'
#  'Serially diluting to  GEN 1 MED_A']
# Progress	: 23%
# ['labware_9' 'A3' 'labware_9' 'A2' '918.75' '918.75' '8'
#  'Serially diluting to  GEN 0.5 MED_A']
# Progress	: 24%
# ['labware_9' 'A2' 'labware_9' 'A1' '787.5' '787.5' '9'
#  'Serially diluting to  GEN 0.25 MED_A']
# Progress	: 25%
# ['labware_9' 'A1' 'labware_10' 'A4' '525' '525' '10'
#  'Serially diluting to  GEN 0.125 MED_A']
# Progress	: 25%
# ['labware_9' 'C4' 'labware_9' 'C3' '1041.796875' '1041.796875' '11'
#  'Serially diluting to  AZT 128 MED_A']
# Progress	: 26%
# ['labware_9' 'C3' 'labware_9' 'C2' '1033.59375' '1033.59375' '12'
#  'Serially diluting to  AZT 64 MED_A']
# Progress	: 27%
# ['labware_9' 'C2' 'labware_9' 'C1' '1017.1875' '1017.1875' '13'
#  'Serially diluting to  AZT 32 MED_A']
# Progress	: 28%
# ['labware_9' 'C1' 'labware_9' 'B5' '984.375' '984.375' '14'
#  'Serially diluting to  AZT 16 MED_A']
# Progress	: 29%
# ['labware_9' 'B5' 'labware_9' 'B4' '918.75' '918.75' '15'
#  'Serially diluting to  AZT 8 MED_A']
# Progress	: 30%
# ['labware_9' 'B4' 'labware_9' 'B3' '787.5' '787.5' '16'
#  'Serially diluting to  AZT 4 MED_A']
# Progress	: 31%
# ['labware_9' 'B3' 'labware_10' 'B1' '525' '525' '17'
#  'Serially diluting to  AZT 2 MED_A']
# Progress	: 32%
# ['labware_10' 'A3' 'labware_4' 'B10, C10, D10' '100' '0' '18'
#  'Distributing  GEN 0 MED_A']
# Progress	: 33%
# ['labware_10' 'A3' 'labware_5' 'B10, C10, D10' '100' '0' '18'
#  'Distributing  GEN 0 MED_A']
# Progress	: 34%
# ['labware_10' 'A3' 'labware_6' 'B10, C10, D10' '100' '0' '18'
#  'Distributing  GEN 0 MED_A']
# Progress	: 35%
# ['labware_10' 'A4' 'labware_4' 'B9, C9, D9' '100' '0' '19'
#  'Distributing  GEN 0.125 MED_A']
# Progress	: 36%
# ['labware_10' 'A4' 'labware_5' 'B9, C9, D9' '100' '0' '19'
#  'Distributing  GEN 0.125 MED_A']
# Progress	: 37%
# ['labware_10' 'A4' 'labware_6' 'B9, C9, D9' '100' '0' '19'
#  'Distributing  GEN 0.125 MED_A']
# Progress	: 38%
# ['labware_10' 'A5' 'labware_4' 'E10, F10, G10' '100' '0' '20'
#  'Distributing  AZT 0 MED_A']
# Progress	: 39%
# ['labware_10' 'A5' 'labware_5' 'E10, F10, G10' '100' '0' '20'
#  'Distributing  AZT 0 MED_A']
# Progress	: 40%
# ['labware_10' 'A5' 'labware_6' 'E10, F10, G10' '100' '0' '20'
#  'Distributing  AZT 0 MED_A']
# Progress	: 41%
# ['labware_10' 'B1' 'labware_4' 'E9, F9, G9' '100' '0' '21'
#  'Distributing  AZT 2 MED_A']
# Progress	: 42%
# ['labware_10' 'B1' 'labware_5' 'E9, F9, G9' '100' '0' '21'
#  'Distributing  AZT 2 MED_A']
# Progress	: 42%
# ['labware_10' 'B1' 'labware_6' 'E9, F9, G9' '100' '0' '21'
#  'Distributing  AZT 2 MED_A']
# Progress	: 43%
# ['labware_9' 'A1' 'labware_4' 'B8, C8, D8' '100' '0' '22'
#  'Distributing  GEN 0.25 MED_A']
# Progress	: 44%
# ['labware_9' 'A1' 'labware_5' 'B8, C8, D8' '100' '0' '22'
#  'Distributing  GEN 0.25 MED_A']
# Progress	: 45%
# ['labware_9' 'A1' 'labware_6' 'B8, C8, D8' '100' '0' '22'
#  'Distributing  GEN 0.25 MED_A']
# Progress	: 46%
# ['labware_9' 'A2' 'labware_4' 'B7, C7, D7' '100' '0' '23'
#  'Distributing  GEN 0.5 MED_A']
# Progress	: 47%
# ['labware_9' 'A2' 'labware_5' 'B7, C7, D7' '100' '0' '23'
#  'Distributing  GEN 0.5 MED_A']
# Progress	: 48%
# ['labware_9' 'A2' 'labware_6' 'B7, C7, D7' '100' '0' '23'
#  'Distributing  GEN 0.5 MED_A']
# Progress	: 49%
# ['labware_9' 'A3' 'labware_4' 'B6, C6, D6' '100' '0' '24'
#  'Distributing  GEN 1 MED_A']
# Progress	: 50%
# ['labware_9' 'A3' 'labware_5' 'B6, C6, D6' '100' '0' '24'
#  'Distributing  GEN 1 MED_A']
# Progress	: 51%
# ['labware_9' 'A3' 'labware_6' 'B6, C6, D6' '100' '0' '24'
#  'Distributing  GEN 1 MED_A']
# Progress	: 52%
# ['labware_9' 'A4' 'labware_4' 'B5, C5, D5' '100' '0' '25'
#  'Distributing  GEN 2 MED_A']
# Progress	: 53%
# ['labware_9' 'A4' 'labware_5' 'B5, C5, D5' '100' '0' '25'
#  'Distributing  GEN 2 MED_A']
# Progress	: 54%
# ['labware_9' 'A4' 'labware_6' 'B5, C5, D5' '100' '0' '25'
#  'Distributing  GEN 2 MED_A']
# Progress	: 55%
# ['labware_9' 'A5' 'labware_4' 'B4, C4, D4' '100' '0' '26'
#  'Distributing  GEN 4 MED_A']
# Progress	: 56%
# ['labware_9' 'A5' 'labware_5' 'B4, C4, D4' '100' '0' '26'
#  'Distributing  GEN 4 MED_A']
# Progress	: 57%
# ['labware_9' 'A5' 'labware_6' 'B4, C4, D4' '100' '0' '26'
#  'Distributing  GEN 4 MED_A']
# Progress	: 58%
# ['labware_9' 'B1' 'labware_4' 'B3, C3, D3' '100' '0' '27'
#  'Distributing  GEN 8 MED_A']
# Progress	: 58%
# ['labware_9' 'B1' 'labware_5' 'B3, C3, D3' '100' '0' '27'
#  'Distributing  GEN 8 MED_A']
# Progress	: 59%
# ['labware_9' 'B1' 'labware_6' 'B3, C3, D3' '100' '0' '27'
#  'Distributing  GEN 8 MED_A']
# Progress	: 60%
# ['labware_9' 'B2' 'labware_4' 'B2, C2, D2' '100' '0' '28'
#  'Distributing  GEN 16 MED_A']
# Progress	: 61%
# ['labware_9' 'B2' 'labware_5' 'B2, C2, D2' '100' '0' '28'
#  'Distributing  GEN 16 MED_A']
# Progress	: 62%
# ['labware_9' 'B2' 'labware_6' 'B2, C2, D2' '100' '0' '28'
#  'Distributing  GEN 16 MED_A']
# Progress	: 63%
# ['labware_9' 'B3' 'labware_4' 'E8, F8, G8' '100' '0' '29'
#  'Distributing  AZT 4 MED_A']
# Progress	: 64%
# ['labware_9' 'B3' 'labware_5' 'E8, F8, G8' '100' '0' '29'
#  'Distributing  AZT 4 MED_A']
# Progress	: 65%
# ['labware_9' 'B3' 'labware_6' 'E8, F8, G8' '100' '0' '29'
#  'Distributing  AZT 4 MED_A']
# Progress	: 66%
# ['labware_9' 'B4' 'labware_4' 'E7, F7, G7' '100' '0' '30'
#  'Distributing  AZT 8 MED_A']
# Progress	: 67%
# ['labware_9' 'B4' 'labware_5' 'E7, F7, G7' '100' '0' '30'
#  'Distributing  AZT 8 MED_A']
# Progress	: 68%
# ['labware_9' 'B4' 'labware_6' 'E7, F7, G7' '100' '0' '30'
#  'Distributing  AZT 8 MED_A']
# Progress	: 69%
# ['labware_9' 'B5' 'labware_4' 'E6, F6, G6' '100' '0' '31'
#  'Distributing  AZT 16 MED_A']
# Progress	: 70%
# ['labware_9' 'B5' 'labware_5' 'E6, F6, G6' '100' '0' '31'
#  'Distributing  AZT 16 MED_A']
# Progress	: 71%
# ['labware_9' 'B5' 'labware_6' 'E6, F6, G6' '100' '0' '31'
#  'Distributing  AZT 16 MED_A']
# Progress	: 72%
# ['labware_9' 'C1' 'labware_4' 'E5, F5, G5' '100' '0' '32'
#  'Distributing  AZT 32 MED_A']
# Progress	: 73%
# ['labware_9' 'C1' 'labware_5' 'E5, F5, G5' '100' '0' '32'
#  'Distributing  AZT 32 MED_A']
# Progress	: 74%
# ['labware_9' 'C1' 'labware_6' 'E5, F5, G5' '100' '0' '32'
#  'Distributing  AZT 32 MED_A']
# Progress	: 75%
# ['labware_9' 'C2' 'labware_4' 'E4, F4, G4' '100' '0' '33'
#  'Distributing  AZT 64 MED_A']
# Progress	: 75%
# ['labware_9' 'C2' 'labware_5' 'E4, F4, G4' '100' '0' '33'
#  'Distributing  AZT 64 MED_A']
# Progress	: 76%
# ['labware_9' 'C2' 'labware_6' 'E4, F4, G4' '100' '0' '33'
#  'Distributing  AZT 64 MED_A']
# Progress	: 77%
# ['labware_9' 'C3' 'labware_4' 'E3, F3, G3' '100' '0' '34'
#  'Distributing  AZT 128 MED_A']
# Progress	: 78%
# ['labware_9' 'C3' 'labware_5' 'E3, F3, G3' '100' '0' '34'
#  'Distributing  AZT 128 MED_A']
# Progress	: 79%
# ['labware_9' 'C3' 'labware_6' 'E3, F3, G3' '100' '0' '34'
#  'Distributing  AZT 128 MED_A']
# Progress	: 80%
# ['labware_9' 'C4' 'labware_4' 'E2, F2, G2' '100' '0' '35'
#  'Distributing  AZT 256 MED_A']
# Progress	: 81%
# ['labware_9' 'C4' 'labware_5' 'E2, F2, G2' '100' '0' '35'
#  'Distributing  AZT 256 MED_A']
# Progress	: 82%
# ['labware_9' 'C4' 'labware_6' 'E2, F2, G2' '100' '0' '35'
#  'Distributing  AZT 256 MED_A']
# Progress	: 83%
# ['labware_11' 'A1' 'labware_4' 'A1, A2, A3, A4, A5, A6, A7, A8' '200' '0'
#  '36' 'Filling outer wells with WATER']
# Progress	: 84%
# ['labware_11' 'A1' 'labware_4' 'A9, A10, A11, A12, B1, B11, B12, C1' '200'
#  '0' '37' 'Filling outer wells with WATER']
# Progress	: 85%
# ['labware_11' 'A1' 'labware_4' 'C11, C12, D1, D11, D12, E1, E11, E12'
#  '200' '0' '38' 'Filling outer wells with WATER']
# Progress	: 86%
# ['labware_11' 'A1' 'labware_4' 'F1, F11, F12, G1, G11, G12, H1, H2' '200'
#  '0' '39' 'Filling outer wells with WATER']
# Progress	: 87%
# ['labware_11' 'A1' 'labware_4' 'H3, H4, H5, H6, H7, H8, H9, H10' '200' '0'
#  '40' 'Filling outer wells with WATER']
# Progress	: 88%
# ['labware_11' 'A1' 'labware_4' 'H11, H12' '200' '0' '41'
#  'Filling outer wells with WATER']
# Progress	: 89%
# ['labware_11' 'A1' 'labware_5' 'A1, A2, A3, A4, A5, A6, A7, A8' '200' '0'
#  '42' 'Filling outer wells with WATER']
# Progress	: 90%
# ['labware_11' 'A1' 'labware_5' 'A9, A10, A11, A12, B1, B11, B12, C1' '200'
#  '0' '43' 'Filling outer wells with WATER']
# Progress	: 91%
# ['labware_11' 'A1' 'labware_5' 'C11, C12, D1, D11, D12, E1, E11, E12'
#  '200' '0' '44' 'Filling outer wells with WATER']
# Progress	: 92%
# ['labware_11' 'A1' 'labware_5' 'F1, F11, F12, G1, G11, G12, H1, H2' '200'
#  '0' '45' 'Filling outer wells with WATER']
# Progress	: 92%
# ['labware_11' 'A1' 'labware_5' 'H3, H4, H5, H6, H7, H8, H9, H10' '200' '0'
#  '46' 'Filling outer wells with WATER']
# Progress	: 93%
# ['labware_11' 'A1' 'labware_5' 'H11, H12' '200' '0' '47'
#  'Filling outer wells with WATER']
# Progress	: 94%
# ['labware_11' 'A1' 'labware_6' 'A1, A2, A3, A4, A5, A6, A7, A8' '200' '0'
#  '48' 'Filling outer wells with WATER']
# Progress	: 95%
# ['labware_11' 'A1' 'labware_6' 'A9, A10, A11, A12, B1, B11, B12, C1' '200'
#  '0' '49' 'Filling outer wells with WATER']
# Progress	: 96%
# ['labware_11' 'A1' 'labware_6' 'C11, C12, D1, D11, D12, E1, E11, E12'
#  '200' '0' '50' 'Filling outer wells with WATER']
# Progress	: 97%
# ['labware_11' 'A1' 'labware_6' 'F1, F11, F12, G1, G11, G12, H1, H2' '200'
#  '0' '51' 'Filling outer wells with WATER']
# Progress	: 98%
# ['labware_11' 'A1' 'labware_6' 'H3, H4, H5, H6, H7, H8, H9, H10' '200' '0'
#  '52' 'Filling outer wells with WATER']
# Progress	: 99%
# ['labware_11' 'A1' 'labware_6' 'H11, H12' '200' '0' '53'
#  'Filling outer wells with WATER']
#
# =====================================================
# SIMULATION COMPLETE -- EVERYTHING SEEMS OKAY (so far)
# =====================================================
# Continue run? (Y/N)y
# Press ENTER to begin run. DON'T FORGET TO PREPARE THE ROBOT DECK
# Failed to initialize character device, will not be able to control gpios (lights, button, smoothiekill, smoothie reset). Only one connection can be made to the gpios at a time. If you need to control gpios, first stop the robot server with systemctl stop opentrons-robot-server. Until you restart the server with systemctl start opentrons-robot-server, you will be unable to control the robot using the Opentrons app.
# /data/deck_calibration.json not found. Loading defaults
# Progress	: 0%
# ['labware_11' 'A1' 'labware_10' 'A3' '1050' '0' '1'
#  'Initial solvent distribution']
# Progress	: 1%
# ['labware_11' 'A1' 'labware_10' 'A4' '525' '0' '1'
#  'Initial solvent distribution']
# Progress	: 2%
# ['labware_11' 'A1' 'labware_9' 'A1' '787.5' '0' '1'
#  'Initial solvent distribution']
# Progress	: 3%
# ['labware_11' 'A1' 'labware_9' 'A2' '918.75' '0' '1'
#  'Initial solvent distribution']
# Progress	: 4%
# ['labware_11' 'A1' 'labware_9' 'A3' '984.375' '0' '1'
#  'Initial solvent distribution']
# Progress	: 5%
# ['labware_11' 'A1' 'labware_9' 'A4' '1017.1875' '0' '1'
#  'Initial solvent distribution']
# Progress	: 6%
# ['labware_11' 'A1' 'labware_9' 'A5' '1033.59375' '0' '1'
#  'Initial solvent distribution']
# Progress	: 7%
# ['labware_11' 'A1' 'labware_9' 'B1' '1041.796875' '0' '1'
#  'Initial solvent distribution']
# Progress	: 8%
# ['labware_11' 'A1' 'labware_9' 'B2' '1438.1103515625' '0' '1'
#  'Initial solvent distribution']
# Progress	: 8%
# ['labware_11' 'A1' 'labware_10' 'A5' '1050' '0' '1'
#  'Initial solvent distribution']
# Progress	: 9%
# ['labware_11' 'A1' 'labware_10' 'B1' '525' '0' '1'
#  'Initial solvent distribution']
# Progress	: 10%
# ['labware_11' 'A1' 'labware_9' 'B3' '787.5' '0' '1'
#  'Initial solvent distribution']
# Progress	: 11%
# ['labware_11' 'A1' 'labware_9' 'B4' '918.75' '0' '1'
#  'Initial solvent distribution']
# Progress	: 12%
# ['labware_11' 'A1' 'labware_9' 'B5' '984.375' '0' '1'
#  'Initial solvent distribution']
# Progress	: 13%
# ['labware_11' 'A1' 'labware_9' 'C1' '1017.1875' '0' '1'
#  'Initial solvent distribution']
# Progress	: 14%
# ['labware_11' 'A1' 'labware_9' 'C2' '1033.59375' '0' '1'
#  'Initial solvent distribution']
# Progress	: 15%
# ['labware_11' 'A1' 'labware_9' 'C3' '1041.796875' '0' '1'
#  'Initial solvent distribution']
# Progress	: 16%
# ['labware_11' 'A1' 'labware_9' 'C4' '1255.078125' '0' '1'
#  'Initial solvent distribution']
# Progress	: 17%
# ['labware_10' 'A1' 'labware_9' 'B2' '653.6865234375' '653.6865234375' '2'
#  'Initial stock dilution']
# Progress	: 18%
# ['labware_10' 'A2' 'labware_9' 'C4' '836.71875' '836.71875' '3'
#  'Initial stock dilution']
# Progress	: 19%
# ['labware_9' 'B2' 'labware_9' 'B1' '1041.796875' '1041.796875' '4'
#  'Serially diluting to  GEN 8 MED_A']
# Progress	: 20%
# ['labware_9' 'B1' 'labware_9' 'A5' '1033.59375' '1033.59375' '5'
#  'Serially diluting to  GEN 4 MED_A']
# Progress	: 21%
# ['labware_9' 'A5' 'labware_9' 'A4' '1017.1875' '1017.1875' '6'
#  'Serially diluting to  GEN 2 MED_A']
# Progress	: 22%
# ['labware_9' 'A4' 'labware_9' 'A3' '984.375' '984.375' '7'
#  'Serially diluting to  GEN 1 MED_A']
# Progress	: 23%
# ['labware_9' 'A3' 'labware_9' 'A2' '918.75' '918.75' '8'
#  'Serially diluting to  GEN 0.5 MED_A']
# Progress	: 24%
# ['labware_9' 'A2' 'labware_9' 'A1' '787.5' '787.5' '9'
#  'Serially diluting to  GEN 0.25 MED_A']
# Progress	: 25%
# ['labware_9' 'A1' 'labware_10' 'A4' '525' '525' '10'
#  'Serially diluting to  GEN 0.125 MED_A']
# Progress	: 25%
# ['labware_9' 'C4' 'labware_9' 'C3' '1041.796875' '1041.796875' '11'
#  'Serially diluting to  AZT 128 MED_A']
# Progress	: 26%
# ['labware_9' 'C3' 'labware_9' 'C2' '1033.59375' '1033.59375' '12'
#  'Serially diluting to  AZT 64 MED_A']
# Progress	: 27%
# ['labware_9' 'C2' 'labware_9' 'C1' '1017.1875' '1017.1875' '13'
#  'Serially diluting to  AZT 32 MED_A']
# Progress	: 28%
# ['labware_9' 'C1' 'labware_9' 'B5' '984.375' '984.375' '14'
#  'Serially diluting to  AZT 16 MED_A']
# Progress	: 29%
# ['labware_9' 'B5' 'labware_9' 'B4' '918.75' '918.75' '15'
#  'Serially diluting to  AZT 8 MED_A']
# Progress	: 30%
# ['labware_9' 'B4' 'labware_9' 'B3' '787.5' '787.5' '16'
#  'Serially diluting to  AZT 4 MED_A']
# Progress	: 31%
# ['labware_9' 'B3' 'labware_10' 'B1' '525' '525' '17'
#  'Serially diluting to  AZT 2 MED_A']
# Progress	: 32%
# ['labware_10' 'A3' 'labware_4' 'B10, C10, D10' '100' '0' '18'
#  'Distributing  GEN 0 MED_A']
# Progress	: 33%
# ['labware_10' 'A3' 'labware_5' 'B10, C10, D10' '100' '0' '18'
#  'Distributing  GEN 0 MED_A']
# Progress	: 34%
# ['labware_10' 'A3' 'labware_6' 'B10, C10, D10' '100' '0' '18'
#  'Distributing  GEN 0 MED_A']
# Progress	: 35%
# ['labware_10' 'A4' 'labware_4' 'B9, C9, D9' '100' '0' '19'
#  'Distributing  GEN 0.125 MED_A']
# Progress	: 36%
# ['labware_10' 'A4' 'labware_5' 'B9, C9, D9' '100' '0' '19'
#  'Distributing  GEN 0.125 MED_A']
# Progress	: 37%
# ['labware_10' 'A4' 'labware_6' 'B9, C9, D9' '100' '0' '19'
#  'Distributing  GEN 0.125 MED_A']
# Progress	: 38%
# ['labware_10' 'A5' 'labware_4' 'E10, F10, G10' '100' '0' '20'
#  'Distributing  AZT 0 MED_A']
# Progress	: 39%
# ['labware_10' 'A5' 'labware_5' 'E10, F10, G10' '100' '0' '20'
#  'Distributing  AZT 0 MED_A']
# Progress	: 40%
# ['labware_10' 'A5' 'labware_6' 'E10, F10, G10' '100' '0' '20'
#  'Distributing  AZT 0 MED_A']
# Progress	: 41%
# ['labware_10' 'B1' 'labware_4' 'E9, F9, G9' '100' '0' '21'
#  'Distributing  AZT 2 MED_A']
# Progress	: 42%
# ['labware_10' 'B1' 'labware_5' 'E9, F9, G9' '100' '0' '21'
#  'Distributing  AZT 2 MED_A']
# Progress	: 42%
# ['labware_10' 'B1' 'labware_6' 'E9, F9, G9' '100' '0' '21'
#  'Distributing  AZT 2 MED_A']
# Progress	: 43%
# ['labware_9' 'A1' 'labware_4' 'B8, C8, D8' '100' '0' '22'
#  'Distributing  GEN 0.25 MED_A']
# Progress	: 44%
# ['labware_9' 'A1' 'labware_5' 'B8, C8, D8' '100' '0' '22'
#  'Distributing  GEN 0.25 MED_A']
# Progress	: 45%
# ['labware_9' 'A1' 'labware_6' 'B8, C8, D8' '100' '0' '22'
#  'Distributing  GEN 0.25 MED_A']
# Progress	: 46%
# ['labware_9' 'A2' 'labware_4' 'B7, C7, D7' '100' '0' '23'
#  'Distributing  GEN 0.5 MED_A']
# Progress	: 47%
# ['labware_9' 'A2' 'labware_5' 'B7, C7, D7' '100' '0' '23'
#  'Distributing  GEN 0.5 MED_A']
# Progress	: 48%
# ['labware_9' 'A2' 'labware_6' 'B7, C7, D7' '100' '0' '23'
#  'Distributing  GEN 0.5 MED_A']
# Progress	: 49%
# ['labware_9' 'A3' 'labware_4' 'B6, C6, D6' '100' '0' '24'
#  'Distributing  GEN 1 MED_A']
# Progress	: 50%
# ['labware_9' 'A3' 'labware_5' 'B6, C6, D6' '100' '0' '24'
#  'Distributing  GEN 1 MED_A']
# Progress	: 51%
# ['labware_9' 'A3' 'labware_6' 'B6, C6, D6' '100' '0' '24'
#  'Distributing  GEN 1 MED_A']
# Progress	: 52%
# ['labware_9' 'A4' 'labware_4' 'B5, C5, D5' '100' '0' '25'
#  'Distributing  GEN 2 MED_A']
# Progress	: 53%
# ['labware_9' 'A4' 'labware_5' 'B5, C5, D5' '100' '0' '25'
#  'Distributing  GEN 2 MED_A']
# Progress	: 54%
# ['labware_9' 'A4' 'labware_6' 'B5, C5, D5' '100' '0' '25'
#  'Distributing  GEN 2 MED_A']
# Progress	: 55%
# ['labware_9' 'A5' 'labware_4' 'B4, C4, D4' '100' '0' '26'
#  'Distributing  GEN 4 MED_A']
# Progress	: 56%
# ['labware_9' 'A5' 'labware_5' 'B4, C4, D4' '100' '0' '26'
#  'Distributing  GEN 4 MED_A']
# Progress	: 57%
# ['labware_9' 'A5' 'labware_6' 'B4, C4, D4' '100' '0' '26'
#  'Distributing  GEN 4 MED_A']
# Progress	: 58%
# ['labware_9' 'B1' 'labware_4' 'B3, C3, D3' '100' '0' '27'
#  'Distributing  GEN 8 MED_A']
# Progress	: 58%
# ['labware_9' 'B1' 'labware_5' 'B3, C3, D3' '100' '0' '27'
#  'Distributing  GEN 8 MED_A']
# Progress	: 59%
# ['labware_9' 'B1' 'labware_6' 'B3, C3, D3' '100' '0' '27'
#  'Distributing  GEN 8 MED_A']
# Progress	: 60%
# ['labware_9' 'B2' 'labware_4' 'B2, C2, D2' '100' '0' '28'
#  'Distributing  GEN 16 MED_A']
# Progress	: 61%
# ['labware_9' 'B2' 'labware_5' 'B2, C2, D2' '100' '0' '28'
#  'Distributing  GEN 16 MED_A']
# Progress	: 62%
# ['labware_9' 'B2' 'labware_6' 'B2, C2, D2' '100' '0' '28'
#  'Distributing  GEN 16 MED_A']
# Progress	: 63%
# ['labware_9' 'B3' 'labware_4' 'E8, F8, G8' '100' '0' '29'
#  'Distributing  AZT 4 MED_A']
# Progress	: 64%
# ['labware_9' 'B3' 'labware_5' 'E8, F8, G8' '100' '0' '29'
#  'Distributing  AZT 4 MED_A']
# Progress	: 65%
# ['labware_9' 'B3' 'labware_6' 'E8, F8, G8' '100' '0' '29'
#  'Distributing  AZT 4 MED_A']
# Progress	: 66%
# ['labware_9' 'B4' 'labware_4' 'E7, F7, G7' '100' '0' '30'
#  'Distributing  AZT 8 MED_A']
# Progress	: 67%
# ['labware_9' 'B4' 'labware_5' 'E7, F7, G7' '100' '0' '30'
#  'Distributing  AZT 8 MED_A']
# Progress	: 68%
# ['labware_9' 'B4' 'labware_6' 'E7, F7, G7' '100' '0' '30'
#  'Distributing  AZT 8 MED_A']
# Progress	: 69%
# ['labware_9' 'B5' 'labware_4' 'E6, F6, G6' '100' '0' '31'
#  'Distributing  AZT 16 MED_A']
# Progress	: 70%
# ['labware_9' 'B5' 'labware_5' 'E6, F6, G6' '100' '0' '31'
#  'Distributing  AZT 16 MED_A']
# Progress	: 71%
# ['labware_9' 'B5' 'labware_6' 'E6, F6, G6' '100' '0' '31'
#  'Distributing  AZT 16 MED_A']
# Progress	: 72%
# ['labware_9' 'C1' 'labware_4' 'E5, F5, G5' '100' '0' '32'
#  'Distributing  AZT 32 MED_A']
# Progress	: 73%
# ['labware_9' 'C1' 'labware_5' 'E5, F5, G5' '100' '0' '32'
#  'Distributing  AZT 32 MED_A']
# Progress	: 74%
# ['labware_9' 'C1' 'labware_6' 'E5, F5, G5' '100' '0' '32'
#  'Distributing  AZT 32 MED_A']
# Progress	: 75%
# ['labware_9' 'C2' 'labware_4' 'E4, F4, G4' '100' '0' '33'
#  'Distributing  AZT 64 MED_A']
# Progress	: 75%
# ['labware_9' 'C2' 'labware_5' 'E4, F4, G4' '100' '0' '33'
#  'Distributing  AZT 64 MED_A']
# Progress	: 76%
# ['labware_9' 'C2' 'labware_6' 'E4, F4, G4' '100' '0' '33'
#  'Distributing  AZT 64 MED_A']
# Progress	: 77%
# ['labware_9' 'C3' 'labware_4' 'E3, F3, G3' '100' '0' '34'
#  'Distributing  AZT 128 MED_A']
# Progress	: 78%
# ['labware_9' 'C3' 'labware_5' 'E3, F3, G3' '100' '0' '34'
#  'Distributing  AZT 128 MED_A']
# Progress	: 79%
# ['labware_9' 'C3' 'labware_6' 'E3, F3, G3' '100' '0' '34'
#  'Distributing  AZT 128 MED_A']
# Progress	: 80%
# ['labware_9' 'C4' 'labware_4' 'E2, F2, G2' '100' '0' '35'
#  'Distributing  AZT 256 MED_A']
# Progress	: 81%
# ['labware_9' 'C4' 'labware_5' 'E2, F2, G2' '100' '0' '35'
#  'Distributing  AZT 256 MED_A']
# Progress	: 82%
# ['labware_9' 'C4' 'labware_6' 'E2, F2, G2' '100' '0' '35'
#  'Distributing  AZT 256 MED_A']
# Progress	: 83%
# ['labware_11' 'A1' 'labware_4' 'A1, A2, A3, A4, A5, A6, A7, A8' '200' '0'
#  '36' 'Filling outer wells with WATER']
# Progress	: 84%
# ['labware_11' 'A1' 'labware_4' 'A9, A10, A11, A12, B1, B11, B12, C1' '200'
#  '0' '37' 'Filling outer wells with WATER']
# Progress	: 85%
# ['labware_11' 'A1' 'labware_4' 'C11, C12, D1, D11, D12, E1, E11, E12'
#  '200' '0' '38' 'Filling outer wells with WATER']
# Progress	: 86%
# ['labware_11' 'A1' 'labware_4' 'F1, F11, F12, G1, G11, G12, H1, H2' '200'
#  '0' '39' 'Filling outer wells with WATER']
# Progress	: 87%
# ['labware_11' 'A1' 'labware_4' 'H3, H4, H5, H6, H7, H8, H9, H10' '200' '0'
#  '40' 'Filling outer wells with WATER']
# Progress	: 88%
# ['labware_11' 'A1' 'labware_4' 'H11, H12' '200' '0' '41'
#  'Filling outer wells with WATER']
# Progress	: 89%
# ['labware_11' 'A1' 'labware_5' 'A1, A2, A3, A4, A5, A6, A7, A8' '200' '0'
#  '42' 'Filling outer wells with WATER']
# Progress	: 90%
# ['labware_11' 'A1' 'labware_5' 'A9, A10, A11, A12, B1, B11, B12, C1' '200'
#  '0' '43' 'Filling outer wells with WATER']
# Progress	: 91%
# ['labware_11' 'A1' 'labware_5' 'C11, C12, D1, D11, D12, E1, E11, E12'
#  '200' '0' '44' 'Filling outer wells with WATER']
# Progress	: 92%
# ['labware_11' 'A1' 'labware_5' 'F1, F11, F12, G1, G11, G12, H1, H2' '200'
#  '0' '45' 'Filling outer wells with WATER']
# Progress	: 92%
# ['labware_11' 'A1' 'labware_5' 'H3, H4, H5, H6, H7, H8, H9, H10' '200' '0'
#  '46' 'Filling outer wells with WATER']
# Progress	: 93%
# ['labware_11' 'A1' 'labware_5' 'H11, H12' '200' '0' '47'
#  'Filling outer wells with WATER']
# Progress	: 94%
# ['labware_11' 'A1' 'labware_6' 'A1, A2, A3, A4, A5, A6, A7, A8' '200' '0'
#  '48' 'Filling outer wells with WATER']
# Progress	: 95%
# ['labware_11' 'A1' 'labware_6' 'A9, A10, A11, A12, B1, B11, B12, C1' '200'
#  '0' '49' 'Filling outer wells with WATER']
# Progress	: 96%
# ['labware_11' 'A1' 'labware_6' 'C11, C12, D1, D11, D12, E1, E11, E12'
#  '200' '0' '50' 'Filling outer wells with WATER']
# Progress	: 97%
# ['labware_11' 'A1' 'labware_6' 'F1, F11, F12, G1, G11, G12, H1, H2' '200'
#  '0' '51' 'Filling outer wells with WATER']
# Progress	: 98%
# ['labware_11' 'A1' 'labware_6' 'H3, H4, H5, H6, H7, H8, H9, H10' '200' '0'
#  '52' 'Filling outer wells with WATER']
# Progress	: 99%
# ['labware_11' 'A1' 'labware_6' 'H11, H12' '200' '0' '53'
#  'Filling outer wells with WATER']
